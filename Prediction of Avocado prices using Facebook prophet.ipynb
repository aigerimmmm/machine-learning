# %%
# PREDICTING AVOCADO PRICES USING FACEBOOK PROPHET
# import libraries 
import pandas as pd # Import Pandas for data manipulation using dataframes
import numpy as np # Import Numpy for data statistical analysis 
import matplotlib.pyplot as plt # Import matplotlib for data visualisation
import random
import seaborn as sns
from fbprophet import Prophet
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
# dataframes creation for both training and testing datasets 
avocado_df = pd.read_csv('/Users/aika/Desktop/DL and ML Practical Tutorials - Package/Project 4/avocado.csv')
avocado_df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
avocado_df = avocado_df.sort_values("Date")
plt.figure(figsize=(10,10))
plt.plot(avocado_df['Date'], avocado_df['AveragePrice'])

# %%
# Bar Chart to indicate the year
plt.figure(figsize=[25,12])
sns.countplot(x = 'year', data = avocado_df)
plt.xticks(rotation = 45)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, '2015'),
#   Text(1, 0, '2016'),
#   Text(2, 0, '2017'),
#   Text(3, 0, '2018')])

# %%
avocado_prophet_df = avocado_df[['Date', 'AveragePrice']]

# %%
avocado_prophet_df
# Out:
#              Date  AveragePrice
# 11569  2015-01-04          1.75
# 9593   2015-01-04          1.49
# 10009  2015-01-04          1.68
# 1819   2015-01-04          1.52
# 9333   2015-01-04          1.64
# ...           ...           ...
# 8574   2018-03-25          1.36
# 9018   2018-03-25          0.70
# 18141  2018-03-25          1.42
# 17673  2018-03-25          1.70
# 8814   2018-03-25          1.34
#
# [18249 rows x 2 columns]

# %%
# STEP 3: MAKE PREDICTIONS

# %%
avocado_prophet_df = avocado_prophet_df.rename(columns={'Date':'ds', 'AveragePrice':'y'})

# %%
avocado_prophet_df
# Out:
#                ds     y
# 11569  2015-01-04  1.75
# 9593   2015-01-04  1.49
# 10009  2015-01-04  1.68
# 1819   2015-01-04  1.52
# 9333   2015-01-04  1.64
# ...           ...   ...
# 8574   2018-03-25  1.36
# 9018   2018-03-25  0.70
# 18141  2018-03-25  1.42
# 17673  2018-03-25  1.70
# 8814   2018-03-25  1.34
#
# [18249 rows x 2 columns]

# %%
m = Prophet()
m.fit(avocado_prophet_df)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 4 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# Forcasting into the future
future = m.make_future_dataframe(periods=365)
forecast = m.predict(future)

# %%
forecast
# Out:
#             ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0   2015-01-04  1.497106    0.907424    1.879613     1.497106     1.497106
# 1   2015-01-11  1.492026    0.907619    1.873492     1.492026     1.492026
# 2   2015-01-18  1.486947    0.896838    1.843276     1.486947     1.486947
# 3   2015-01-25  1.481868    0.838372    1.828886     1.481868     1.481868
# 4   2015-02-01  1.476788    0.837324    1.829765     1.476788     1.476788
# ..         ...       ...         ...         ...          ...          ...
# 529 2019-03-21  1.164077    0.538147    1.590519     0.978589     1.355415
# 530 2019-03-22  1.163350    0.544931    1.600227     0.976622     1.355676
# 531 2019-03-23  1.162624    0.560575    1.594712     0.974759     1.355938
# 532 2019-03-24  1.161897    0.523580    1.591819     0.973764     1.356199
# 533 2019-03-25  1.161171    0.560123    1.624059     0.972986     1.356481
#
#      additive_terms  additive_terms_lower  additive_terms_upper    yearly  \
# 0         -0.113156             -0.113156             -0.113156 -0.113156
# 1         -0.104632             -0.104632             -0.104632 -0.104632
# 2         -0.104303             -0.104303             -0.104303 -0.104303
# 3         -0.123309             -0.123309             -0.123309 -0.123309
# 4         -0.151727             -0.151727             -0.151727 -0.151727
# ..              ...                   ...                   ...       ...
# 529       -0.086194             -0.086194             -0.086194 -0.086194
# 530       -0.084516             -0.084516             -0.084516 -0.084516
# 531       -0.082564             -0.082564             -0.082564 -0.082564
# 532       -0.080358             -0.080358             -0.080358 -0.080358
# 533       -0.077925             -0.077925             -0.077925 -0.077925
#
#      yearly_lower  yearly_upper  multiplicative_terms  \
# 0       -0.113156     -0.113156                   0.0
# 1       -0.104632     -0.104632                   0.0
# 2       -0.104303     -0.104303                   0.0
# 3       -0.123309     -0.123309                   0.0
# 4       -0.151727     -0.151727                   0.0
# ..            ...           ...                   ...
# 529     -0.086194     -0.086194                   0.0
# 530     -0.084516     -0.084516                   0.0
# 531     -0.082564     -0.082564                   0.0
# 532     -0.080358     -0.080358                   0.0
# 533     -0.077925     -0.077925                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 0                           0.0                         0.0  1.383950
# 1                           0.0                         0.0  1.387394
# 2                           0.0                         0.0  1.382644
# 3                           0.0                         0.0  1.358559
# 4                           0.0                         0.0  1.325062
# ..                          ...                         ...       ...
# 529                         0.0                         0.0  1.077883
# 530                         0.0                         0.0  1.078834
# 531                         0.0                         0.0  1.080060
# 532                         0.0                         0.0  1.081540
# 533                         0.0                         0.0  1.083246
#
# [534 rows x 16 columns]

# %%
figure = m.plot(forecast, xlabel='Date', ylabel='Price')

# %%
figure3 = m.plot_components(forecast)

# %%
# predicting trend for specific region
avocado_df_sample = avocado_df[avocado_df['region']=='West']

# %%
avocado_df_sample
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 11881          51  2015-01-04          1.40     187548.30    70313.71
# 2755           51  2015-01-04          0.89    5794410.58  2275446.87
# 11880          50  2015-01-11          1.39     223156.55    80139.16
# 2754           50  2015-01-11          0.95    5333097.71  2203111.92
# 2753           49  2015-01-18          0.96    5475363.01  2431736.63
# ...           ...         ...           ...           ...         ...
# 9104            2  2018-03-11          1.00    6906412.50  2442241.76
# 18226           1  2018-03-18          1.73     210067.47    33437.98
# 9103            1  2018-03-18          0.99    7254940.65  2099082.66
# 9102            0  2018-03-25          0.93    7667064.46  2567279.74
# 18225           0  2018-03-25          1.60     271723.08    26996.28
#
#              4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 11881    72942.11      24.30    44268.18    10023.72    34244.46         0.00
# 2755   2582300.65   97024.09   839638.97   688813.01   150819.57         6.39
# 11880   111395.01      63.88    31558.50     9296.76    22261.74         0.00
# 2754   2292761.26  127412.09   709812.44   598705.08   111073.82        33.54
# 2753   2258069.63   76348.13   709208.62   527358.78   181809.88        39.96
# ...           ...        ...         ...         ...         ...          ...
# 9104   1695925.97  130983.00  2637261.77  1435608.59  1184730.56     16922.62
# 18226    47165.54     110.40   129353.55    73163.12    56020.24       170.19
# 9103   1707752.84  115997.93  3332107.22  1333247.05  1982086.02     16774.15
# 9102   1912986.38  118289.91  3068508.43  1309580.19  1745630.06     13298.18
# 18225    77861.39     117.56   166747.85    87108.00    79495.39       144.46
#
#                type  year region
# 11881       organic  2015   West
# 2755   conventional  2015   West
# 11880       organic  2015   West
# 2754   conventional  2015   West
# 2753   conventional  2015   West
# ...             ...   ...    ...
# 9104   conventional  2018   West
# 18226       organic  2018   West
# 9103   conventional  2018   West
# 9102   conventional  2018   West
# 18225       organic  2018   West
#
# [338 rows x 14 columns]

# %%
avocado_df_sample = avocado_df_sample.sort_values("Date")

# %%
plt.figure(figsize=(10,10))
plt.plot(avocado_df_sample['Date'], avocado_df_sample['AveragePrice'])
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
avocado_df_sample = avocado_df_sample.rename(columns={'Date':'ds', 'AveragePrice':'y'})

# %%
m = Prophet()
m.fit(avocado_df_sample)
# Forcasting into the future
future = m.make_future_dataframe(periods=365)
forecast = m.predict(future)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
figure = m.plot(forecast, xlabel='Date', ylabel='Price')

# %%
figure3 = m.plot_components(forecast)
